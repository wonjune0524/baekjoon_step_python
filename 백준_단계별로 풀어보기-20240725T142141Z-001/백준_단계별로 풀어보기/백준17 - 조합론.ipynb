# %%
# 01

N = int(input())
print((N - 1) * N)
# Out:
# 5
# 20

# %%
# 02

N = int(input())
print(2 ** N)
# Out:
# 4
# 16

# %%
# 03

import math

N = int(input())
print(math.factorial(N))
# Out:
# 10
# 3628800

# %%
# 04

import math

N, K = map(int, input().split())
print(math.comb(N, K))
# Out:
# 5 2
# 10

# %%
# 05

import math

T = int(input())

for _ in range(T):
  N, M = map(int, input().split())
  print(math.comb(M, N))
# Out:
# 3
# 2 2
# 1
# 1 5
# 5
# 13 29
# 67863915
